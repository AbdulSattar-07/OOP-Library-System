# %% [markdown]
# #### Library Management

# %%
class Person:                     #Base Class
    def __init__(self,name,age,contact_number):
        self.name = name
        self.age = age
        self.contact_number= contact_number
    def get_details(self):
        return f"Person name : {self.name} \n Person age: {self.age} \n Contact Number: {self.contact_number} "
    def update_contact(self,new_contact_number):
        self.new_contact_number= new_contact_number
        self.contact_number=new_contact_number
        return f"Updated Contact Number is :{self.contact_number}"
class Librarian(Person):
    def __init__(self, name, age, contact_number,employee_id):
        super().__init__(name, age, contact_number)
        self.employee_id = employee_id
    def add_book(self,book,library):
        library.books.append(book)
        return f"The Book {book.title} is added in Library"
        
    def remove_book(self,book_id,library):
        for book in library.books:
            if book.book_id == book_id:
                library.books.remove(book)
                return f"The Book {book.title} is removed from Library"
            else:
                return f"Book with ID {book_id} not found in Library"
    def add_member(self,member,library):
        library.members.append(member)
        return f"The Member {member.name} is added to Library!"
    def remove_member(self,member_id,library):
        for member in library.members:
            if member.member_id == member_id:
                library.members.remove(member)
                return f"The Member {member.name} is removed from Library"
            else:
                return f"Member with ID {member_id} not found in Library"
class LibraryMember(Person):
    def __init__(self, name, age, contact_number,member_id):
        super().__init__(name, age, contact_number)
        self.member_id = member_id
        self.borrowed_books = []
    def borrow_book(self):
        
        pass
    def return_book(self):
        pass
    def view_borrowed_books(self):
        pass
class Book(Person):
    def __init__(self,book_id,title,author,avalibility):
        self.book_id = book_id
        self.title = title
        self.author=author
        self.avalibility = avalibility
    def check_availability(self):
        pass
    def update_availability(self):
        pass    
        
class Library(Person):
    def __init__(self,books,members,librarians):
        self.books= books 
        self.members = members
        self.librarians = librarians
    def display_books(self):
        pass
    def register_member(self,members):
        pass
    def deregister_member(self, member_id,):
        pass
    def find_book(self,book_id):
        pass
    def lend_book(self ,book_id,member_id):
        pass
    def return_book(self ,book_id,member_id):
        pass
